# %% [markdown]
# # 1. Imports and Data load
# <a id="1"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_colwidth', None)

from sklearn.decomposition import TruncatedSVD

from warnings import simplefilter
simplefilter("ignore")

# %%
ratings_df_no_0 = pd.read_csv('data/ratings_transformed.csv')
books_df = pd.read_csv('data/books_transformed.csv')

# %% [markdown]
# # 2. New Dataframe: Ratings by Author
# <a id="2"></a>

# %% [markdown]
# I am creating a new dataframe by merging the previous dataframes.

# %%
book_ratings = pd.merge(ratings_df_no_0, books_df, on='ISBN')

book_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276726  0155061224            5
# 1   276729  052165615X            3
# 2   276729  0521795028            6
# 3   276744  038550120X            7
# 4   276747  0060517794            9
#
#                                                        Book-Title  \
# 0                                                Rites of Passage
# 1                                                  Help!: Level 1
# 2  The Amsterdam Connection : Level 4 (Cambridge English Readers)
# 3                                                 A Painted House
# 4                                        Little Altars Everywhere
#
#      Book-Author  Year-Of-Publication                   Publisher
# 0     Judith Rae                 2001                      Heinle
# 1  Philip Prowse                 1999  Cambridge University Press
# 2    Sue Leather                 2001  Cambridge University Press
# 3   JOHN GRISHAM                 2001                   Doubleday
# 4  Rebecca Wells                 2003                 HarperTorch

# %% [markdown]
# It is clear that there are multiple editions of the books, maybe even several different translations.
#
# This is why I prefer to extract a new dataframe by grouping the authors and calculating their scores averaged over their books.

# %%
author_ratings = book_ratings.groupby(['User-ID', 'Book-Author'])['Book-Rating'].mean().reset_index(name='Avg Rating')

author_ratings.head()
# Out:
#    User-ID           Book-Author  Avg Rating
# 0        8           Ann Beattie         5.0
# 1        8          Julia Oliver         7.0
# 2        8     Loren D. Estleman         6.0
# 3        8          R. J. Kaiser         5.0
# 4        8  Richard Bruce Wright         5.0

# %% [markdown]
# If I try to do the following steps on the full dataset, the kernel crashes because of the large amount of data to be processed.
#
# To run the code successfully, I can either:
# * Use big data tools, like Apache Spark.
# * Reduce the dimension of the dataset by using only a fraction of it.
#
# Here, I will follow the second strategy.

# %%
len(author_ratings)
# Out:
# 322135

# %% [markdown]
# I will only keep the authors that are in the top 500 authors' list.

# %%
author_count = books_df['Book-Author'].value_counts().reset_index(name='Count').sort_values('Count', ascending=False).head(500)

author_count.tail()

top_500_authors = author_count[author_count['Book-Author'] != 'Not Applicable (Na )']['Book-Author'].to_list()

len(top_500_authors)
# Out:
# 499

# %%
reduced_author_ratings = author_ratings[author_ratings['Book-Author'].isin(top_500_authors)]

len(reduced_author_ratings)
# Out:
# 74777

# %% [markdown]
# The dataframe is still big. Thus, I will further cut its dimension.

# %%
reduced_author_ratings = reduced_author_ratings.iloc[0:5000]

print(len(reduced_author_ratings))

reduced_author_ratings.head()
# Out:
# 5000
#     User-ID                   Book-Author  Avg Rating
# 2         8             Loren D. Estleman         6.0
# 7         9                 Toni Morrison         6.0
# 10       14  Mary-Kate &amp; Ashley Olsen         5.0
# 12       16              Michael Crichton         9.0
# 13       17               Agatha Christie         7.0

# %%
mean_rating = reduced_author_ratings['Avg Rating'].mean()

mean_rating
# Out:
# np.float64(7.523748647762592)

# %% [markdown]
# Finally, I need to pivot the data to get it into a user-item matrix format. I will also fill the null user ratings with 'mean_rating'.

# %%
X = reduced_author_ratings.pivot(index='User-ID', columns='Book-Author', values='Avg Rating').fillna(mean_rating)

print(X.shape)

X.head()
# Out:
# (1946, 477)
# Book-Author  A. A. Milne  Agatha Christie  Alan Dean Foster  Albert Camus  \
# User-ID
# 8               7.523749         7.523749          7.523749      7.523749
# 9               7.523749         7.523749          7.523749      7.523749
# 14              7.523749         7.523749          7.523749      7.523749
# 16              7.523749         7.523749          7.523749      7.523749
# 17              7.523749         7.000000          7.523749      7.523749
#
# Book-Author  Aldous Huxley  Alexandre Dumas  Alice Hoffman  Alice Walker  \
# User-ID
# 8                 7.523749         7.523749       7.523749      7.523749
# 9                 7.523749         7.523749       7.523749      7.523749
# 14                7.523749         7.523749       7.523749      7.523749
# 16                7.523749         7.523749       7.523749      7.523749
# 17                7.523749         7.523749       7.523749      7.523749
#
# Book-Author  Alistair MacLean   Amy Tan  ...  Walter Mosley  Warren Murphy  \
# User-ID                                  ...
# 8                    7.523749  7.523749  ...       7.523749       7.523749
# 9                    7.523749  7.523749  ...       7.523749       7.523749
# 14                   7.523749  7.523749  ...       7.523749       7.523749
# 16                   7.523749  7.523749  ...       7.523749       7.523749
# 17                   7.523749  7.523749  ...       7.523749       7.523749
#
# Book-Author  Whitley Strieber  Wilkie Collins  Willa Cather  William Faulkner  \
# User-ID
# 8                    7.523749        7.523749      7.523749          7.523749
# 9                    7.523749        7.523749      7.523749          7.523749
# 14                   7.523749        7.523749      7.523749          7.523749
# 16                   7.523749        7.523749      7.523749          7.523749
# 17                   7.523749        7.523749      7.523749          7.523749
#
# Book-Author  William Shakespeare  William Shatner  Wolfgang Hohlbein  \
# User-ID
# 8                       7.523749         7.523749           7.523749
# 9                       7.523749         7.523749           7.523749
# 14                      7.523749         7.523749           7.523749
# 16                      7.523749         7.523749           7.523749
# 17                      7.523749         7.523749           7.523749
#
# Book-Author  Zane Grey
# User-ID
# 8             7.523749
# 9             7.523749
# 14            7.523749
# 16            7.523749
# 17            7.523749
#
# [5 rows x 477 columns]

# %% [markdown]
# # 3. Book Author Recommender
# <a id="4"></a>

# %% [markdown]
# ## 3.1 Number of Truncated SVD Components

# %% [markdown]
# The first step is to center the data.

# %%
X_centered = X - X.mean()

X_centered.head()
# Out:
# Book-Author  A. A. Milne  Agatha Christie  Alan Dean Foster  Albert Camus  \
# User-ID
# 8              -0.000489        -0.001106          0.000036     -0.004527
# 9              -0.000489        -0.001106          0.000036     -0.004527
# 14             -0.000489        -0.001106          0.000036     -0.004527
# 16             -0.000489        -0.001106          0.000036     -0.004527
# 17             -0.000489        -0.524854          0.000036     -0.004527
#
# Book-Author  Aldous Huxley  Alexandre Dumas  Alice Hoffman  Alice Walker  \
# User-ID
# 8                -0.005005        -0.000245       0.002682     -0.002778
# 9                -0.005005        -0.000245       0.002682     -0.002778
# 14               -0.005005        -0.000245       0.002682     -0.002778
# 16               -0.005005        -0.000245       0.002682     -0.002778
# 17               -0.005005        -0.000245       0.002682     -0.002778
#
# Book-Author  Alistair MacLean   Amy Tan  ...  Walter Mosley  Warren Murphy  \
# User-ID                                  ...
# 8                    0.001297 -0.005192  ...       0.002422       0.000538
# 9                    0.001297 -0.005192  ...       0.002422       0.000538
# 14                   0.001297 -0.005192  ...       0.002422       0.000538
# 16                   0.001297 -0.005192  ...       0.002422       0.000538
# 17                   0.001297 -0.005192  ...       0.002422       0.000538
#
# Book-Author  Whitley Strieber  Wilkie Collins  Willa Cather  William Faulkner  \
# User-ID
# 8                   -0.000734        0.001089     -0.002447          0.001627
# 9                   -0.000734        0.001089     -0.002447          0.001627
# 14                  -0.000734        0.001089     -0.002447          0.001627
# 16                  -0.000734        0.001089     -0.002447          0.001627
# 17                  -0.000734        0.001089     -0.002447          0.001627
#
# Book-Author  William Shakespeare  William Shatner  Wolfgang Hohlbein  \
# User-ID
# 8                      -0.008658         0.003866            0.00301
# 9                      -0.008658         0.003866            0.00301
# 14                     -0.008658         0.003866            0.00301
# 16                     -0.008658         0.003866            0.00301
# 17                     -0.008658         0.003866            0.00301
#
# Book-Author  Zane Grey
# User-ID
# 8            -0.000489
# 9            -0.000489
# 14           -0.000489
# 16           -0.000489
# 17           -0.000489
#
# [5 rows x 477 columns]

# %% [markdown]
# After centering the data, I will fit a truncated SVD model with all the columns.

# %%
svdAll = TruncatedSVD(n_components=X_centered.shape[1])

UAll = svdAll.fit_transform(X_centered)

# %% [markdown]
# Then, I will plot the cumulative explained variance ratios to find a cut-off value for the number of components.

# %%
cum_evrAll = list(zip(range(1, UAll.shape[1] + 1), np.cumsum(svdAll.explained_variance_ratio_)))

cum_evrAll_df = pd.DataFrame(cum_evrAll).set_index(0)

cum_evrAll_df.plot(title='Number of Components vs Cumulative Explained Variance Ratio',
                xlabel='Components',
                ylabel='Cumulative Explained Variance Ratio',
                legend=False)

plt.tight_layout()

# %% [markdown]
# The plot shows that 200 components are enough to explain more than 80% of the cumulative explained variance ratio.

# %% [markdown]
# ## 3.2 Update the model to 200 components

# %%
svd200 = TruncatedSVD(n_components=200)

U200 = svd200.fit_transform(X_centered)

# %%
cum_evr200 = list(zip(range(1, U200.shape[1] + 1), np.cumsum(svd200.explained_variance_ratio_)))

cum_evr200_df = pd.DataFrame(cum_evr200).set_index(0)

cum_evr200_df.plot(title='Number of Components vs Cumulative Explained Variance Ratio',
                xlabel='Components',
                ylabel='Cumulative Explained Variance Ratio',
                legend=False)

plt.tight_layout()

# %% [markdown]
# ## 3.3 Create a New User

# %% [markdown]
# I want to make recommendations for a new user.
#
# First, I am creating a new user and I am filling its columns with NaNs.

# %%
vector_length = X_centered.shape[1]
new_user = np.full(vector_length, np.nan)

new_user_df = pd.DataFrame([new_user], columns=X_centered.columns)
new_user_df

new_user_df
# Out:
# Book-Author  A. A. Milne  Agatha Christie  Alan Dean Foster  Albert Camus  \
# 0                    NaN              NaN               NaN           NaN
#
# Book-Author  Aldous Huxley  Alexandre Dumas  Alice Hoffman  Alice Walker  \
# 0                      NaN              NaN            NaN           NaN
#
# Book-Author  Alistair MacLean  Amy Tan  ...  Walter Mosley  Warren Murphy  \
# 0                         NaN      NaN  ...            NaN            NaN
#
# Book-Author  Whitley Strieber  Wilkie Collins  Willa Cather  William Faulkner  \
# 0                         NaN             NaN           NaN               NaN
#
# Book-Author  William Shakespeare  William Shatner  Wolfgang Hohlbein  \
# 0                            NaN              NaN                NaN
#
# Book-Author  Zane Grey
# 0                  NaN
#
# [1 rows x 477 columns]

# %% [markdown]
# Then, I am assigning different values to a few of these cells. These would be the ratings by the new user.

# %%
new_user_df['Albert Camus'] = 8
new_user_df['Agatha Christie'] = 5
new_user_df['William Shakespeare'] = 9
new_user_df['Franz Kafka'] = 10
new_user_df['Walt Disney Productions'] = 4
new_user_df['Italo Calvino'] = 8

new_user_df
# Out:
# Book-Author  A. A. Milne  Agatha Christie  Alan Dean Foster  Albert Camus  \
# 0                    NaN                5               NaN             8
#
# Book-Author  Aldous Huxley  Alexandre Dumas  Alice Hoffman  Alice Walker  \
# 0                      NaN              NaN            NaN           NaN
#
# Book-Author  Alistair MacLean  Amy Tan  ...  Walter Mosley  Warren Murphy  \
# 0                         NaN      NaN  ...            NaN            NaN
#
# Book-Author  Whitley Strieber  Wilkie Collins  Willa Cather  William Faulkner  \
# 0                         NaN             NaN           NaN               NaN
#
# Book-Author  William Shakespeare  William Shatner  Wolfgang Hohlbein  \
# 0                              9              NaN                NaN
#
# Book-Author  Zane Grey
# 0                  NaN
#
# [1 rows x 477 columns]

# %% [markdown]
# As a check, I can view only the authors rated by the user.

# %%
new_user_df.T.dropna()
# Out:
#                             0
# Book-Author
# Agatha Christie           5.0
# Albert Camus              8.0
# Franz Kafka              10.0
# Italo Calvino             8.0
# Walt Disney Productions   4.0
# William Shakespeare       9.0

# %% [markdown]
# ## 3.4 Create Recommendations for the New User

# %% [markdown]
# First of all, I have to fill the NaN values in the new user's columns. Then, I am centering the data.

# %%
new_user_fillna_df = new_user_df.fillna(mean_rating)

# center the data
new_user_centered_df = new_user_fillna_df - X.mean()

new_user_centered_df
# Out:
# Book-Author  A. A. Milne  Agatha Christie  Alan Dean Foster  Albert Camus  \
# 0              -0.000489        -2.524854          0.000036      0.471724
#
# Book-Author  Aldous Huxley  Alexandre Dumas  Alice Hoffman  Alice Walker  \
# 0                -0.005005        -0.000245       0.002682     -0.002778
#
# Book-Author  Alistair MacLean   Amy Tan  ...  Walter Mosley  Warren Murphy  \
# 0                    0.001297 -0.005192  ...       0.002422       0.000538
#
# Book-Author  Whitley Strieber  Wilkie Collins  Willa Cather  William Faulkner  \
# 0                   -0.000734        0.001089     -0.002447          0.001627
#
# Book-Author  William Shakespeare  William Shatner  Wolfgang Hohlbein  \
# 0                       1.467593         0.003866            0.00301
#
# Book-Author  Zane Grey
# 0            -0.000489
#
# [1 rows x 477 columns]

# %% [markdown]
# Then, I am transforming the user into the latent space.

# %%
new_user_200d = svd200.transform(new_user_centered_df)

print(new_user_200d.shape)

new_user_200d
# Out:
# (1, 200)
# array([[-0.03558631,  0.03399825, -0.14935937,  0.06590714, -0.2131917 ,
#          0.09571035, -0.09214573,  0.32466183,  0.34091421, -0.0429196 ,
#          0.28783685,  0.09930283, -0.12870667,  0.05207935,  0.00159996,
#         -0.01203442,  0.07787011, -0.00434825,  0.23473799, -0.29279923,
#          0.48861485, -0.02212455, -0.04086567,  0.00701145, -0.12095313,
#          0.79532012, -0.45650163, -0.31254471,  0.27016678,  0.19822102,
#         -0.47890103, -0.24341733,  0.31975239, -0.32499498, -0.21770516,
#         -0.15994484, -0.0440802 , -0.04700863, -0.08328272,  0.12297365,
#         -0.08689947,  0.00147415, -0.01765304, -0.00560219,  0.00974492,
#          0.12546087, -0.00361897, -0.03323419, -0.36390179,  0.24505084,
#          0.12276361, -0.06895998,  0.09606271,  0.02286644, -0.09467992,
#          0.02323379, -0.25909788,  0.14748828,  0.11165802,  0.23520657,
#          0.03535831,  0.10107923, -0.08323307, -0.05667758, -0.02120338,
#          0.1680454 ,  0.15414275,  0.41885603,  0.14005785,  0.00303991,
#         -0.03477112, -0.02741415, -0.08882759, -0.08756912,  0.07764648,
#          0.23929509,  0.23841815,  0.11630623, -0.06908459,  0.09233833,
#          0.71527769,  0.38661766, -0.29882476,  0.15782317, -0.26863525,
#         -0.0394419 , -0.5995935 , -0.28172541,  0.1010156 ,  0.07628761,
#          0.58838341, -0.10010386, -0.01999638, -0.36899614, -0.16413169,
#         -0.08741035, -0.26947106, -0.13461414,  0.00124197,  0.0649026 ,
#         -0.423109  , -0.08797059, -0.01065551,  0.54984641, -0.17059449,
#          0.30229092,  0.06255111, -0.40900504, -0.20247017,  0.0648874 ,
#         -0.00901112, -0.3387448 ,  0.09065268, -0.05904662,  0.19495349,
#          0.22891539,  0.23646522,  0.32991007,  0.38750681, -0.53699728,
#          0.21017446, -0.52282997, -0.29791129, -0.18267371,  0.27253813,
#          0.04415603, -0.20129994,  0.28704931,  0.21300981, -0.18997802,
#         -0.75585685, -0.46221364, -0.33695119,  0.15811361,  0.57806776,
#          0.01542666,  0.2272489 ,  1.01199654,  0.15885953, -0.11023846,
#         -0.60452023, -0.11862745, -0.35940154, -0.11426081, -0.6041232 ,
#          0.81189189, -0.17953023, -0.27826748, -0.03603371, -0.32647675,
#          0.17885692,  0.00178316, -0.70737319,  0.14411426,  0.64476151,
#          0.49874995, -0.08536034,  0.43430864, -0.07893483, -0.05314826,
#          0.02183091, -0.25289672, -0.50003219, -0.02968759,  0.02830519,
#         -0.27134198, -0.07882122, -0.11101987,  0.04366458,  0.02140034,
#          0.02389879,  0.29897341, -0.12290543,  0.03468242, -0.098732  ,
#         -0.19506788,  0.24827982, -0.36228132, -0.06147397,  0.10932356,
#         -3.85788331e-03,  5.55052688e-03,  3.75802836e-05,
#         -1.25362921e-02,  1.32452053e-02, -3.41844096e-02,
#          1.19438272e-03, -1.11751316e-02,  4.78483377e-03,
#          1.34094144e-02, -6.68036122e-02, -1.08796175e-02,
#         -2.04502032e-03, -1.32213405e-02,  1.40538948e-03,
#         -2.92386241e-05,  1.08653901e-02,  2.11046823e-02,
#          2.32872443e-02,  2.27739169e-02,  7.49197609e-02,
#          8.74087834e-03, -2.53491590e-02, -2.20715269e-03,
#         -5.86579598e-03, -7.53628630e-04,  5.14682805e-02,
#          2.33057564e-02,  1.39203729e-02,  4.62623811e-02,
#          1.84444156e-02,  5.86609852e-03,  9.63373637e-03,
#          2.83350123e-02, -2.71284939e-02,  1.31322479e-02,
#          7.19482785e-03,  1.12411342e-02,  3.99362485e-03,
#          1.35626181e-03,  6.76381029e-03,  2.09937064e-02,
#          5.80998354e-03,  7.57124195e-04, -1.08876603e-02,
#          2.55051308e-02, -1.55709545e-02, -3.17763649e-03,
#          2.63664082e-02,  1.74397463e-02,  3.31037678e-04,
#          6.47302862e-03, -2.01026927e-02,  1.35208663e-02,
#          5.34047059e-03,  1.99599352e-04,  2.64908287e-02,
#         -2.91807506e-02,  1.13294916e-02,  2.52517631e-02,
#          9.88998038e-03, -3.66887038e-02,  1.60535173e-02,
#         -1.43226628e-03,  2.85402086e-02,  7.78102625e-02,
#          1.90366767e-02, -1.58942778e-03, -3.67589012e-02,
#          1.18588092e-01, -3.67194545e-02,  1.16873515e-02,
#          5.36126229e-04, -2.91794008e-02, -2.29062580e-02,
#         -4.76820587e-03, -2.91420195e-02,  1.44655488e+00,
#          3.34618825e-02, -5.70687438e-02, -3.75955937e-03]])

# %% [markdown]
# I am making recommendation for the new user and then I am sorting them.

# %%
new_user_recs = pd.DataFrame(new_user_pred, columns=X.columns)

top_recs = new_user_recs.T.sort_values(by=0, ascending=False)
top_recs.columns = ['Predicted_Rating']
top_recs.reset_index(inplace=True)
top_recs.head()
# Out:
#            Book-Author  Predicted_Rating
# 0          Franz Kafka          2.387919
# 1  William Shakespeare          1.446555
# 2         Albert Camus          0.187123
# 3    Joan Lowery Nixon          0.174566
# 4         Barbara Park          0.173645

# %% [markdown]
# To get a more useful output, I am excluding the book authors that the user had already recommended himself.

# %%
already_rated = new_user_df.T.dropna().index

top_recs_final = top_recs[~top_recs['Book-Author'].isin(already_rated)]
top_recs_final.head(10)
# Out:
#                  Book-Author  Predicted_Rating
# 3          Joan Lowery Nixon          0.174566
# 4               Barbara Park          0.173645
# 5       Laura Ingalls Wilder          0.165198
# 6                Eve Bunting          0.157528
# 7                Walt Disney          0.118588
# 8   Gertrude Chandler Warner          0.110085
# 9            Donald J. Sobol          0.106107
# 10                Max Lucado          0.103242
# 11               Henry James          0.103059
# 12                John Jakes          0.095747

# %% [markdown]
# # References
#
# * Alice Zhao (Maven Analytics), Python Data Science: Unsupervised Machine Learning, course on Udemy.
